# %% [markdown]
# # Llama 3.1 8B — Base vs Fine-tuned Inference
#
# Compare base Llama 3.1 8B-Instruct against your LoRA fine-tuned version via Gradio.
#
# ## Setup
#
# 1. **Set runtime to T4 GPU**
# 2. **Update paths in Cell 1** — adapter path + experiment log paths on Drive
# 3. **Run all cells** — Gradio launches with a shareable link
#
# ### Tabs
# - **Generate:** Live generation, toggle between base and fine-tuned (same model, adapter on/off — zero extra VRAM)
# - **Saved Outputs:** Browse canary prompt outputs from your experiment logs side by side

# %%
# === Cell 1: Install + mount + config ===
# !pip install -q transformers peft bitsandbytes accelerate gradio

import torch, re
from google.colab import drive
drive.mount("/content/drive")

DRIVE_BASE = "/content/drive/MyDrive/voice-ft"
ADAPTER_PATH = f"{DRIVE_BASE}/adapters/llama-voice-v1"

# Paths to saved canary output logs (copy from repo's 4_experiments/)
BASELINE_PATH = f"{DRIVE_BASE}/experiment-logs/llama_baselines.md"
FINETUNED_PATH = f"{DRIVE_BASE}/experiment-logs/llama_finetuned.md"

GEN_KWARGS = dict(
    temperature=0.8,
    top_p=0.9,
    top_k=50,
    repetition_penalty=1.1,
    do_sample=True,
)

# %%
# === Cell 2: Load model (base + LoRA adapter) ===
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig
from peft import PeftModel
from huggingface_hub import login
from google.colab import userdata

login(token=userdata.get("HF_TOKEN"))

MODEL_ID = "meta-llama/Llama-3.1-8B-Instruct"

bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.float16,
    bnb_4bit_use_double_quant=True,
)

print("Loading base Llama in 4-bit...")
base_model = AutoModelForCausalLM.from_pretrained(
    MODEL_ID, quantization_config=bnb_config, device_map="auto",
)

print("Applying LoRA adapter...")
model = PeftModel.from_pretrained(base_model, ADAPTER_PATH)
tokenizer = AutoTokenizer.from_pretrained(ADAPTER_PATH)

print(f"Ready on {model.device}")

# %%
# === Cell 3: Generate + parse saved outputs ===

def generate(variant, prompt, max_tokens):
    """Generate with base (adapter off) or fine-tuned (adapter on)."""
    if variant == "Base":
        model.disable_adapter_layers()
    else:
        model.enable_adapter_layers()

    messages = [{"role": "user", "content": prompt}]
    input_text = tokenizer.apply_chat_template(
        messages, tokenize=False, add_generation_prompt=True
    )
    inputs = tokenizer(input_text, return_tensors="pt").to(model.device)
    input_len = inputs["input_ids"].shape[1]
    with torch.no_grad():
        output = model.generate(**inputs, **GEN_KWARGS, max_new_tokens=int(max_tokens))
    return tokenizer.decode(output[0][input_len:], skip_special_tokens=True)


def parse_canary_file(filepath):
    """Parse canary output markdown into {letter: [sample1, sample2, ...]}."""
    try:
        with open(filepath) as f:
            text = f.read()
    except FileNotFoundError:
        return None

    canaries = {}
    sections = re.split(r'## Canary ([A-C])', text)
    for i in range(1, len(sections), 2):
        letter = sections[i]
        content = sections[i + 1] if i + 1 < len(sections) else ""
        samples = re.split(r'### Sample \d+\s*\n', content)
        samples = [s.strip() for s in samples[1:] if s.strip()]
        canaries[letter] = samples
    return canaries


base_canaries = parse_canary_file(BASELINE_PATH)
ft_canaries = parse_canary_file(FINETUNED_PATH)

if base_canaries:
    print(f"Loaded baselines: {', '.join(f'Canary {k} ({len(v)} samples)' for k, v in base_canaries.items())}")
else:
    print(f"Baseline file not found at {BASELINE_PATH}")

if ft_canaries:
    print(f"Loaded fine-tuned: {', '.join(f'Canary {k} ({len(v)} samples)' for k, v in ft_canaries.items())}")
else:
    print(f"Fine-tuned file not found at {FINETUNED_PATH}")

# %%
# === Cell 4: Launch Gradio ===
import gradio as gr


def show_canary(canary, sample_num):
    idx = int(sample_num) - 1
    base_text, ft_text = "File not loaded", "File not loaded"

    if base_canaries and canary in base_canaries:
        s = base_canaries[canary]
        base_text = s[idx] if idx < len(s) else f"Only {len(s)} samples available"
    if ft_canaries and canary in ft_canaries:
        s = ft_canaries[canary]
        ft_text = s[idx] if idx < len(s) else f"Only {len(s)} samples available"

    return base_text, ft_text


initial_base, initial_ft = show_canary("A", 1)

with gr.Blocks(title="Lily's Voice — Llama 3.1 8B") as demo:
    gr.Markdown("# Lily's Voice — Llama 3.1 8B\nBase vs LoRA fine-tuned on Lily's Substack essays.")

    with gr.Tab("Generate"):
        variant = gr.Radio(["Base", "Fine-tuned"], value="Fine-tuned", label="Model")
        prompt = gr.Textbox(label="Prompt", lines=4, placeholder="Write an essay about...")
        max_tokens = gr.Slider(128, 2048, value=1024, step=128, label="Max tokens")
        gen_btn = gr.Button("Generate", variant="primary")
        output = gr.Textbox(label="Output", lines=30)
        gr.Examples(
            [
                ["Fine-tuned", "Write a personal Substack Note about class in America, from the perspective of a Chinese first-gen immigrant whose family is lower-middle class.", 512],
                ["Base", "Write a personal Substack Note about class in America, from the perspective of a Chinese first-gen immigrant whose family is lower-middle class.", 512],
                ["Fine-tuned", "Write an essay about Jacques Ellul as a forgotten prophet of propaganda and technological conformity.", 1024],
            ],
            inputs=[variant, prompt, max_tokens],
        )
        gen_btn.click(generate, [variant, prompt, max_tokens], output)

    with gr.Tab("Saved Canary Outputs"):
        gr.Markdown("Saved outputs from experiment logs. Base and fine-tuned side by side.")
        with gr.Row():
            canary_radio = gr.Radio(["A", "B", "C"], value="A", label="Canary Prompt")
            sample_slider = gr.Slider(1, 5, value=1, step=1, label="Sample #")
        with gr.Row():
            base_box = gr.Textbox(label="Base Llama", lines=25, value=initial_base)
            ft_box = gr.Textbox(label="Fine-tuned Llama", lines=25, value=initial_ft)

        canary_radio.change(show_canary, [canary_radio, sample_slider], [base_box, ft_box])
        sample_slider.change(show_canary, [canary_radio, sample_slider], [base_box, ft_box])

demo.queue()
demo.launch(share=True)
